# %%
acdc14324b55833b42b3c8e1016ae387

# %%
import requests
import pandas as pd
import json

key = 'acdc14324b55833b42b3c8e1016ae387'
movieCd='20204548'

url='http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={}&movieCd={}'.format(key, movieCd)

response = requests.get(url)
r_data = response.json()
# movieinfoResult = pd.DataFrame(r_data['movieInfoResult'])
# movieinfoResult_actor = pd.DataFrame(r_data['movieInfoResult']['movieInfo']['actors']) # 배우
# movieinfoResult_actor
# -------------------------------------
#df_head = movieinfoResult_actor.head()
#df_head.transpose()
#df_head.T
#df_head[["peopleNm"]]
# --------------------------------------

# print(df_head[peopleNm])
#b1=b1[b1['관객수']>=1000]
#b1.to_csv("1000.csv",index=False, encoding='utf-8-sig')

# ---------------------------------------------------
print(r_data)
#dic_r_data=json.loads(r_data) #dic으로 볍환
#dic_r_data.values()
# Out:
# {'movieInfoResult': {'movieInfo': {'movieCd': '20204548', 'movieNm': '범죄도시 2', 'movieNmEn': 'The Roundup', 'movieNmOg': '', 'showTm': '105', 'prdtYear': '2022', 'openDt': '20220518', 'prdtStatNm': '개봉', 'typeNm': '장편', 'nations': [{'nationNm': '한국'}], 'genres': [{'genreNm': '범죄'}, {'genreNm': '액션'}], 'directors': [{'peopleNm': '이상용', 'peopleNmEn': 'Lee Sang-yong'}], 'actors': [{'peopleNm': '마동석', 'peopleNmEn': 'Don LEE', 'cast': '마석도', 'castEn': ''}, {'peopleNm': '손석구', 'peopleNmEn': 'SON Sukku', 'cast': '강해상', 'castEn': ''}, {'peopleNm': '최귀화', 'peopleNmEn': 'CHOI Gwi-hwa', 'cast': '전일만', 'castEn': ''}, {'peopleNm': '박지환', 'peopleNmEn': 'PARK Ji-hwan', 'cast': '장이수', 'castEn': ''}, {'peopleNm': '허동원', 'peopleNmEn': 'HEO Dong-won', 'cast': '오동균', 'castEn': ''}, {'peopleNm': '송하준', 'peopleNmEn': '', 'cast': '강홍석', 'castEn': ''}, {'peopleNm': '정재광', 'peopleNmEn': 'JEONG Jae-gwang', 'cast': '김상훈', 'castEn': ''}, {'peopleNm': '남문철', 'peopleNmEn': 'NAM Mun-cheol', 'cast': '최춘백', 'castEn':
# ...

# %%
import pandas as pd
df=pd.read_excel("1000over_eng.xlsx")
df
#열 추가하는 법
# 1000over_eng["actor"]=값
# Out:
#     rank             title  startdate         sales  attendance  screen  \
# 0      1                명량 2014-07-30  135758208810    17615844    1587
# 1      2              극한직업 2019-01-23  139655543516    16266338    2003
# 2      3         신과함께-죄와 벌 2017-12-20  115727528087    14414658    1912
# 3      4              국제시장 2014-12-17  110945002730    14264059    1044
# 4      5        어벤져스: 엔드게임 2019-04-24  122492181020    13977602    2835
# 5      6            겨울왕국 2 2019-11-21  114810421450    13747792    2648
# 6      7               베테랑 2015-08-05  105170856250    13414484    1115
# 7      8               아바타 2009-12-17  125304346000    13338863     917
# 8      9               도둑들 2012-07-25   93672497700    12984701    1091
# 9     10           7번방의 선물 2013-01-23   91437368170    12812144     866
# 10    11               알라딘 2019-05-23  109041960039    12797927    1409
# 11    12                암살 2015-07-22   98468733781    12706855    1519
# ...
